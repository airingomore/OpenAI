# %%
import openai

# %%
from dotenv import dotenv_values
config = dotenv_values(".env")
openai.api_key = config['OPEN_API_KEY']
assert openai.api_key.startswith('sk-'), 'Error loading the API key. The API key should start with "sk-""'

# %%
q1 = 'What are the healthiest foods to eat every day?'
q2 = 'Make a recipe with those foods'
q3 = 'What is the amoun kcal?'

messages = [
    {'role':'system','content': 'Answer as concisely as possible'},
    {'role':'user','content': q1}
]

response = openai.ChatCompletion.create(
    model='gpt-3.5-turbo',
    messages=messages,
    temperature=0.7
)

bot_response_1 = response.choices[0]['message']['content']
print(bot_response_1)

print()
print('-' * 50)
print()

messages = [
    {'role':'system','content': 'Answer as concisely as possible'},
    {'role':'user','content': q1},
    {'role':'assistant','content':bot_response_1},
    {'role':'user','content': q2}

]

response = openai.ChatCompletion.create(
    model='gpt-3.5-turbo',
    messages=messages,
    temperature=0.7
)

bot_response_2 = response.choices[0]['message']['content']
print(bot_response_2)

print()
print('-' * 50)
print()

messages = [
    {'role':'system','content': 'Answer as concisely as possible'},
    {'role':'user','content': q1},
    {'role':'assistant','content':bot_response_1},
    {'role':'user','content': q2},
    {'role':'assistant','content':bot_response_2},
    {'role':'user','content': q3},

]

response = openai.ChatCompletion.create(
    model='gpt-3.5-turbo',
    messages=messages,
    temperature=0.7
)

bot_response_3 = response.choices[0]['message']['content']
print(bot_response_3)
# Out:
# Some of the healthiest foods to eat every day include fruits, vegetables, whole grains, lean proteins (such as fish, poultry, and legumes), and healthy fats (such as avocados, nuts, and olive oil).
#
# --------------------------------------------------
#
# Here's a recipe for a nutritious and delicious salad using some of the healthiest foods:
#
# Quinoa Salad with Roasted Vegetables and Lemon Vinaigrette
#
# Ingredients:
# - 1 cup quinoa, cooked according to package instructions
# - 1 cup mixed roasted vegetables (such as bell peppers, zucchini, and carrots)
# - 1 cup cherry tomatoes, halved
# - 1/2 cup cucumber, diced
# - 1/4 cup red onion, thinly sliced
# - 1/4 cup fresh parsley, chopped
# - 1/4 cup feta cheese, crumbled (optional)
#
# For the Lemon Vinaigrette:
# - 2 tablespoons extra virgin olive oil
# - 1 tablespoon fresh lemon juice
# - 1 teaspoon honey or maple syrup (optional)
# - Salt and pepper to taste
#
# Instructions:
# 1. In a large bowl, combine the cooked quinoa, roasted vegetables, cherry tomatoes, cucumber, red onion, and parsley.
#
# 2. In a small bowl, whisk together the olive oil, lemon juice, honey or maple syrup (if using), salt, and pepper to make the vinaigrette.
#
# 3. Pour the vinaigrette over the salad and toss well to combine.
#
# 4. Sprinkle crumbled feta cheese on top (if desired).
#
# 5. Serve the salad immediately or refrigerate for later. It can be enjoyed as a side dish or a light meal on its own.
#
# Enjoy this nutritious and vibrant quinoa salad packed with whole grains, roasted vegetables, and a tangy lemon vinaigrette!
#
# --------------------------------------------------
#
# The number of calories in the recipe can vary depending on the specific ingredients used and the portion sizes. However, here is a rough estimate of the calorie content:
#
# - 1 cup cooked quinoa: approximately 220 calories
# - 1 cup mixed roasted vegetables: around 100-150 calories (depending on the vegetables used and cooking method)
# - 1 cup cherry tomatoes: about 25 calories
# - 1/2 cup cucumber: around 10 calories
# - 1/4 cup red onion: approximately 20 calories
# - 1/4 cup fresh parsley: about 5 calories
# - 1/4 cup feta cheese: around 70 calories (optional)
# - Lemon vinaigrette: approximately 120-150 calories (depending on the amount used)
#
# Please note that these are rough estimates and can vary based on specific ingredients and preparation methods.

# %%
import time

questions = list()
bot_responses = list()
messages = list()


system_prompt = input('System prompt: ')
if system_prompt == '':
    system_prompt = 'Answer as concisely as possible.'

messages.append({'role':'system', 'content':system_prompt})
while True:
    current_question = input('Me: ')
    if current_question.lower() in ['exit','quit']:
        print('Chat Bot: I was happy to assist you. Bye bye!')
        time.sleep(2)
        break
    if current_question == '':
        continue
    
    messages.append({'role':'user', 'content':current_question})
    questions.append(current_question)
    
    response = openai.ChatCompletion.create(
        model='gpt-3.5-turbo',
        messages = messages,
        temperature=0.7,
        max_tokens=3000
    )
    
    current_response = response.choices[0]['message']['content']
    print(f'\nChat Bot: {current_response}')
    bot_responses.append(current_response)
    
    messages.append({'role':'assistant', 'content':current_response})
    
    print('\n'+ '-' *50 + '\n')
    
print()
print(dict(zip(questions,bot_responses)))
print()
print(messages)
# Out:
# System prompt: Answer me in spanish even if the questions are in other language
# Me: A resume of the book "1984"
#
# Chat Bot: "1984" es una novela distópica escrita por George Orwell y publicada en 1949. La historia se desarrolla en un futuro imaginario, en el año titular de 1984, en una sociedad totalitaria llamada Oceanía. El protagonista, Winston Smith, trabaja en el Ministerio de la Verdad donde altera y falsifica registros históricos para cumplir con la propaganda del Partido. El gobierno está encabezado por el Gran Hermano, una figura omnipresente que controla todos los aspectos de la vida de los ciudadanos.
#
# En esta sociedad, la libertad individual está completamente suprimida y la vigilancia constante es la norma. La novela retrata la opresión del Estado en la vida de los ciudadanos, donde el pensamiento independiente es considerado un crimen y se castiga severamente. Winston se rebela contra el sistema y comienza una relación clandestina con Julia, una mujer que también está en contra del régimen.
#
# A medida que la historia avanza, Winston y Julia son descubiertos y capturados por la Policía del Pensamiento. Ambos son torturados y sometidos a un intenso lavado de cerebro para que renuncien a sus creencias y acepten las enseñanzas del Partido. La novela culmina con la rendición total de Winston y su aceptación de la ideología del gobierno. El mensaje central de "1984" es la advertencia sobre los peligros del totalitarismo y la importancia de defender la libertad y la verdad.
#
# En resumen, "1984" es una obra maestra literaria que explora temas como la opresión gubernamental, la privación de libertad y la lucha por la resistencia individual en un mundo distópico.
#
# --------------------------------------------------
#
# Me: Who was the author?
#
# Chat Bot: El autor de "1984" es George Orwell.
#
# --------------------------------------------------
#
# Me: quit
# Chat Bot: I was happy to assist you. Bye bye!
#
